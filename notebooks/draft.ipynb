# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
img_path = "../imgs/girl.png"

# %%
img = cv2.imread(img_path)
org = (100, 100)
window_name = "test"
font = cv2.FONT_HERSHEY_SIMPLEX
fontScale = 2
color = (0, 0, 255)
thickness = 1

# %%
#https://stackoverflow.com/questions/28816046/
#displaying-different-images-with-actual-size-in-matplotlib-subplot
def display(im_path):
    dpi = 80
    im_data = plt.imread(im_path)

    height, width  = im_data.shape[:2]
    
    # What size does the figure need to be in inches to fit the image?
    figsize = width / float(dpi), height / float(dpi)

    # Create a figure of the right size with one axes that takes up the full figure
    fig = plt.figure(figsize=figsize)
    ax = fig.add_axes([0, 0, 1, 1])

    # Hide spines, ticks, etc.
    ax.axis('off')

    # Display the image.
    ax.imshow(im_data, cmap='gray')

    plt.show()

# %%
def write_img(img_name, img):
    new_img = cv2.imwrite(f"../imgs/{img_name}.png", img)
    return new_img

# %%
display(img_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23968\2554919304.py in <module>
# ----> 1 display(img_path)
#
# ~\AppData\Local\Temp\ipykernel_23968\2351949242.py in display(im_path)
#       3 def display(im_path):
#       4     dpi = 80
# ----> 5     im_data = plt.imread(im_path)
#       6
#       7     height, width  = im_data.shape[:2]
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2158 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2159 def imread(fname, format=None):
# -> 2160     return matplotlib.image.imread(fname, format)
#    2161
#    2162
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1558                     response = io.BytesIO(response.read())
#    1559                 return imread(response, format=ext)
# ...

# %%
text_image = cv2.putText(img, 'OpenCv', org, font, fontScale, color, thickness,  cv2.LINE_AA)

# %%
cv2.imwrite("../imgs/text2.png", text_image)
# Out:
# True

# %%
text2 = "../imgs/text.png"
display(text2)

# %%
# Create a black image
img = np.zeros((512,512,3), np.uint8)
imgs_path = "../imgs/"

# %%
write_img("black", img)
# Out:
# True

# %%
black = "../imgs/black.png"

# %%
display(black)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23968\1487833816.py in <module>
# ----> 1 display(black)
#
# ~\AppData\Local\Temp\ipykernel_23968\2351949242.py in display(im_path)
#       3 def display(im_path):
#       4     dpi = 80
# ----> 5     im_data = plt.imread(im_path)
#       6
#       7     height, width  = im_data.shape[:2]
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in imread(fname, format)
#    2158 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2159 def imread(fname, format=None):
# -> 2160     return matplotlib.image.imread(fname, format)
#    2161
#    2162
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1558                     response = io.BytesIO(response.read())
#    1559                 return imread(response, format=ext)
# ...
