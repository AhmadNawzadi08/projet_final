# %%
# !pip install deepface

# %%
from deepface import DeepFace
# Out:
# Directory  C:\Users\admin /.deepface created
# Directory  C:\Users\admin /.deepface/weights created

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread(r'C:\Users\admin\Pictures\elon1.jpg')
plt.imshow(img1)
plt.show()
img2 = cv2.imread(r'C:\Users\admin\Pictures\elon4.png')
plt.imshow(img2)
plt.show()

# %%
result = DeepFace.verify(img1, img2)
# Out:
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 167ms/step

# %%
print("is same face:", result["verified"])
# Out:
# is same face: True
